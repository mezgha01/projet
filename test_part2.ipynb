# %%
import matplotlib.pyplot as plt

# %%
from pylab import *

# %%
x=linspace(0,5,10)
y=x**2

# %%
x
# Out:
# array([0.        , 0.55555556, 1.11111111, 1.66666667, 2.22222222,
#        2.77777778, 3.33333333, 3.88888889, 4.44444444, 5.        ])

# %%
plot(x,y,'r')

# %%
figure()
plot(x,y,'r')
xlabel('x')
ylabel('y')
title('title')
show()

# %%
subplot(1,2,1)
plot(x,y,'r--')
subplot(1,2,2)
plot(y,x,'g*-')

# %%
:
fig = figure() #create new figure object 

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

axes.plot(x, y, 'r') # plot red line

axes.set_xlabel('x') # set xlabel
axes.set_ylabel('y') # set ylabel
axes.set_title('title'); # set title
# Out:
#   File "<ipython-input-8-c4841fc0378b>", line 1
#     :
#     ^
# SyntaxError: invalid syntax

# %%
fig = figure() #create new figure object 

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

axes.plot(x, y, 'r') # plot red line

axes.set_xlabel('x') # set xlabel
axes.set_ylabel('y') # set ylabel
axes.set_title('title'); # set title

# %%
fig = figure(figsize=(8,4),dip=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-047a571e9fa6> in <module>
# ----> 1 fig = figure(figsize=(8,4),dip=100)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     543                                         frameon=frameon,
#     544                                         FigureClass=FigureClass,
# --> 545                                         **kwargs)
#     546
#     547         if figLabel:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3249         from matplotlib.figure import Figure
#    3250         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3251         fig = fig_cls(*args, **kwargs)
# ...

# %%
fig = figure(figsize=(8,4),dpi=100)

# %%
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3620769c9274> in <module>
# ----> 1 ax.set_xlabel("x")
#       2 ax.set_ylabel("y")
#
# NameError: name 'ax' is not defined

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot(x, y, 'r')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')
    ax.legend(["curves1","curves2","curves3"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-bd0ec0f5fd3a> in <module>
# ----> 1 fig, axes = plt.subplots(nrows=1, ncols=2)
#       2
#       3 for ax in axes:
#       4     ax.plot(x, y, 'r')
#       5     ax.set_xlabel('x')
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot(x, y, 'r')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')
    ax.legend(["curves1","curves2","curves3"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-99a19f24b8be> in <module>
#       3
#       4 for ax in axes:
# ----> 5     ax.plot(x, y, 'r')
#       6     ax.set_xlabel('x')
#       7     ax.set_ylabel('y')
#
# NameError: name 'x' is not defined

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:

    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')
    ax.legend(["curves1","curves2","curves3"])

# %%
ax.plot(x, x**2, label="curve1")
ax.plot(x, x**3, label="curve2")
ax.legend();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-16df36038335> in <module>
# ----> 1 ax.plot(x, x**2, label="curve1")
#       2 ax.plot(x, x**3, label="curve2")
#       3 ax.legend();
#
# NameError: name 'x' is not defined

# %%
x=linspace(0,5,10)
y=x**2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c0c9f4037dde> in <module>
# ----> 1 x=linspace(0,5,10)
#       2 y=x**2
#
# NameError: name 'linspace' is not defined

# %%
import *
# Out:
#   File "<ipython-input-7-730b1f7ad8c9>", line 1
#     import *
#            ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
x=linspace(0,5,10)
y=x**2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e82e8246116d> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 x=linspace(0,5,10)
#       3 y=x**2
#
# NameError: name 'linspace' is not defined

# %%
from pylab import *

# %%
x=linspace(0,5,10)
y=x**2

# %%
ax.plot(x, x**2, label="curve1")
ax.plot(x, x**3, label="curve2")
ax.legend();

# %%
import numpy as np
arr = np.array([1,5,3,9])

# %%
arr
# Out:
# array([1, 5, 3, 9])

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
np.ones(5)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
np.arange(7)
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
np.diag([1,2,3])
# Out:
# array([[1, 0, 0],
#        [0, 2, 0],
#        [0, 0, 3]])

# %%
np.diag([1,3,5,4])
# Out:
# array([[1, 0, 0, 0],
#        [0, 3, 0, 0],
#        [0, 0, 5, 0],
#        [0, 0, 0, 4]])

# %%
M=np.array([[1,2],[4,5]])

# %%
M
# Out:
# array([[1, 2],
#        [4, 5]])

# %%
arr=np.random.randn(5)

# %%
arr
# Out:
# array([-1.18763367,  1.34280124,  1.01443025, -0.57247778,  1.67390011])

# %%
stockholm_td_adj.dat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-d07066e0de0f> in <module>
# ----> 1 stockholm_td_adj.dat
#
# NameError: name 'stockholm_td_adj' is not defined

# %%
data = np.genfromtxt('stockholm_td_adj.dat')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-24-ec67325c42a3> in <module>
# ----> 1 data = np.genfromtxt('stockholm_td_adj.dat')
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    1742             fname = os_fspath(fname)
#    1743         if isinstance(fname, basestring):
# -> 1744             fhd = iter(np.lib._datasource.open(fname, 'rt', encoding=encoding))
#    1745             own_fhd = True
#    1746         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\_datasource.py in open(path, mode, destpath, encoding, newline)
#     264
# ...

# %%
data = np.genfromtxt('stockholm_td_adj.dat')

# %%
data
# Out:
# array([[ 1.800e+03,  1.000e+00,  1.000e+00, ..., -6.100e+00, -6.100e+00,
#          1.000e+00],
#        [ 1.800e+03,  1.000e+00,  2.000e+00, ..., -1.540e+01, -1.540e+01,
#          1.000e+00],
#        [ 1.800e+03,  1.000e+00,  3.000e+00, ..., -1.500e+01, -1.500e+01,
#          1.000e+00],
#        ...,
#        [ 2.011e+03,  1.200e+01,  2.900e+01, ...,  4.200e+00,  4.200e+00,
#          1.000e+00],
#        [ 2.011e+03,  1.200e+01,  3.000e+01, ..., -1.000e-01, -1.000e-01,
#          1.000e+00],
#        [ 2.011e+03,  1.200e+01,  3.100e+01, ..., -3.300e+00, -3.300e+00,
#          1.000e+00]])

# %%
# !head data
# Out:
# 'head' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex‚cutable ou un fichier de commandes.

# %%
data.shape
# Out:
# (77431, 7)

# %%
# !head stockholm_td_adj.dat
# Out:
# 'head' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex‚cutable ou un fichier de commandes.

# %%
fig, ax = subplots(figsize=(14,4))
ax.plot(data[:,0]+data[:,1]/12.0+data[:,2]/365, data[:,5])
ax.axis('tight')
ax.set_title('tempeatures in Stockholm')
ax.set_xlabel('year')
ax.set_ylabel('temperature (C)');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3fc5320a564a> in <module>
# ----> 1 fig, ax = subplots(figsize=(14,4))
#       2 ax.plot(data[:,0]+data[:,1]/12.0+data[:,2]/365, data[:,5])
#       3 ax.axis('tight')
#       4 ax.set_title('tempeatures in Stockholm')
#       5 ax.set_xlabel('year')
#
# NameError: name 'subplots' is not defined

# %%
import numpy as np

# %%
fig, ax = subplots(figsize=(14,4))
ax.plot(data[:,0]+data[:,1]/12.0+data[:,2]/365, data[:,5])
ax.axis('tight')
ax.set_title('tempeatures in Stockholm')
ax.set_xlabel('year')
ax.set_ylabel('temperature (C)');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3fc5320a564a> in <module>
# ----> 1 fig, ax = subplots(figsize=(14,4))
#       2 ax.plot(data[:,0]+data[:,1]/12.0+data[:,2]/365, data[:,5])
#       3 ax.axis('tight')
#       4 ax.set_title('tempeatures in Stockholm')
#       5 ax.set_xlabel('year')
#
# NameError: name 'subplots' is not defined

# %%
from pylab import *

# %%
fig, ax = subplots(figsize=(14,4))
ax.plot(data[:,0]+data[:,1]/12.0+data[:,2]/365, data[:,5])
ax.axis('tight')
ax.set_title('tempeatures in Stockholm')
ax.set_xlabel('year')
ax.set_ylabel('temperature (C)');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3fc5320a564a> in <module>
#       1 fig, ax = subplots(figsize=(14,4))
# ----> 2 ax.plot(data[:,0]+data[:,1]/12.0+data[:,2]/365, data[:,5])
#       3 ax.axis('tight')
#       4 ax.set_title('tempeatures in Stockholm')
#       5 ax.set_xlabel('year')
#
# NameError: name 'data' is not defined

# %%
data = np.genfromtxt('stockholm_td_adj.dat')
fig, ax = subplots(figsize=(14,4))
ax.plot(data[:,0]+data[:,1]/12.0+data[:,2]/365, data[:,5])
ax.axis('tight')
ax.set_title('tempeatures in Stockholm')
ax.set_xlabel('year')
ax.set_ylabel('temperature (C)');

# %%
data
# Out:
# array([[ 1.800e+03,  1.000e+00,  1.000e+00, ..., -6.100e+00, -6.100e+00,
#          1.000e+00],
#        [ 1.800e+03,  1.000e+00,  2.000e+00, ..., -1.540e+01, -1.540e+01,
#          1.000e+00],
#        [ 1.800e+03,  1.000e+00,  3.000e+00, ..., -1.500e+01, -1.500e+01,
#          1.000e+00],
#        ...,
#        [ 2.011e+03,  1.200e+01,  2.900e+01, ...,  4.200e+00,  4.200e+00,
#          1.000e+00],
#        [ 2.011e+03,  1.200e+01,  3.000e+01, ..., -1.000e-01, -1.000e-01,
#          1.000e+00],
#        [ 2.011e+03,  1.200e+01,  3.100e+01, ..., -3.300e+00, -3.300e+00,
#          1.000e+00]])

# %%
# !head stockholm_td_adj.dat
# Out:
# 'head' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex‚cutable ou un fichier de commandes.

# %%
head stockholm_td_adj.dat
# Out:
#   File "<ipython-input-11-d17e4db3c78b>", line 1
#     head stockholm_td_adj.dat
#                         ^
# SyntaxError: invalid syntax

# %%
M=rand(3,3)

# %%
M
# Out:
# array([[0.28342992, 0.37746241, 0.38211022],
#        [0.58228173, 0.25244373, 0.64743456],
#        [0.32357585, 0.83209222, 0.84934548]])

# %%
import numpy as np

# %%
np.savetxt('random_matrix.csv',M)

# %%
# !get-content random_matrix.csv
# Out:
# 'get-content' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex‚cutable ou un fichier de commandes.

# %%
import os

# %%
# !cat random_matrix.csv
# Out:
# 'cat' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex‚cutable ou un fichier de commandes.

# %%
np.save("random-matrix.npy", M)

# !file random-matrix.npy
# Out:
# 'file' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex‚cutable ou un fichier de commandes.
